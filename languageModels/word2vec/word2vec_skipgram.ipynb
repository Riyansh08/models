# %% [markdown]
# # Word2vec (Skipgram Algorithm) (softmax)

# %%
import torch 
import torch.nn as nn 
import torch.optim as optim 
from collections import Counter
import numpy as np

# %% [markdown]
# Preparing the dataset

# %%
class Word2VecDataset: 
    def __init__(self , corpus , window_size = 2):
        self.corpus = corpus 
        self.window_size = window_size
        self.word_to_idx , self.idx_to_word , self.vocab_size = self.build_vocab()
        self.data = self.generate_to_training_pairs()
        
    
    def build_vocab(self):
        words = [word for sentence in self.corpus for word in sentence]
        word_counts = Counter(words)
        vocab = list(word_counts.keys())
        word_to_idx = { word : idx for idx ,  word in enumerate(vocab)}
        idx_to_word = {idx:word for word , idx in word_to_idx.items()}
        return word_to_idx , idx_to_word , len(vocab)
    
    
    def generate_training_pairs(self):
        pairs = []

        for sentence in self.corpus:
            indices = [self.word_to_idx[word] for word in sentence]
            for center_pos , center_idx in enumerate(indices):
             for offset in range(-self.window_size  , self.window_size + 1):
                context_pos = center_pos + offset 
                if context_pos >=0 and context_pos < len(indices) and context_pos != center_pos:
                    pairs.append((center_idx , indices[context_pos]))
                    
        return pairs

# %%
class Word2Vec(nn.Module):
    def __init__(self , vocab_size , embedding_dim):
        super(Word2Vec , self).__init__()
        self.center_embedding = nn.Embedding(vocab_size , embedding_dim)
        self.outside_embedding = nn.Embedding(self.vocab_size , embedding_dim)
        
        
    def forward(self , center_words):
        center_embeds  = self.center_embedding(center_words)
        return center_embeds 
    
    
    def predict(self , center_embeds):
        logits = torch.matmul(center_embeds , self.outside_embedding.T)
        probs = torch.softmax(logits , dim = 1 )
        return probs

# %%
class Softmaxloss(nn.Module):
    def __init__(self):
        super(Softmaxloss  , self).__init__()
        
    def forward(self , center_embeds  , target_indices , model):
        logits = torch.matmul(center_embeds , model.outside_embeddings.weight.T)
        log_probs = torch.log_softmax(logits , dim = 1 )
        loss = -torch.sum(log_probs[range(log_probs.size(0) , target_indices)])
        return loss

# %%
def train_word2vec_softmax(dataset , embedding_dim = 10 , epochs = 10 , learning_rate =  0.01):
    vocab_size = dataset.vocab_size
    model = Word2Vec(vocab_size , embedding_dim)
    loss_fn = Softmaxloss()
    
    optimizer = optim.SGD(model.parameters() , lr = learning_rate)
    
    
    for epoch in range(epochs):
        total_loss = 0 
        for center_idx, outside_idx in dataset.data:
            # Convert to tensors
            center_tensor = torch.tensor([center_idx], dtype=torch.long)
            outside_tensor = torch.tensor([outside_idx], dtype=torch.long)

            # Forward pass
            center_embeds = model(center_tensor)
            loss = loss_fn(center_embeds, outside_tensor, model)

            # Backward pass
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        print(f"Epoch {epoch + 1}, Loss: {total_loss:.4f}")

    return model , total_loss


# Example Usage for Softmax
corpus = [
    ["I", "like", "learning", "deep", "learning"],
    ["deep", "learning", "is", "fun"],
    ["word2vec", "uses", "word", "embeddings"]
]

dataset = Word2VecDataset(corpus)
trained_model_softmax = train_word2vec_softmax(dataset)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from collections import Counter

# Step 1: Dataset Preparation
class Word2VecDataset:
    def __init__(self, corpus, window_size=2):
        self.corpus = corpus
        self.window_size = window_size
        self.word_to_idx, self.idx_to_word, self.vocab_size = self.build_vocab()
        self.data = self.generate_training_pairs()

    def build_vocab(self):
        words = [word for sentence in self.corpus for word in sentence]
        word_counts = Counter(words)
        vocab = list(word_counts.keys())
        word_to_idx = {word: idx for idx, word in enumerate(vocab)}
        idx_to_word = {idx: word for word, idx in word_to_idx.items()}
        return word_to_idx, idx_to_word, len(vocab)

    def generate_training_pairs(self):
        pairs = []
        for sentence in self.corpus:
            indices = [self.word_to_idx[word] for word in sentence]
            for center_pos, center_idx in enumerate(indices):
                for offset in range(-self.window_size, self.window_size + 1):
                    context_pos = center_pos + offset
                    if context_pos >= 0 and context_pos < len(indices) and context_pos != center_pos:
                        pairs.append((center_idx, indices[context_pos]))
        return pairs


# Step 2: Word2Vec Model
class Word2Vec(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super(Word2Vec, self).__init__()
        self.center_embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.outside_embeddings = nn.Embedding(vocab_size, embedding_dim)

    def forward(self, center_words):
        center_embeds = self.center_embeddings(center_words)
        return center_embeds

    def predict(self, center_embeds):
        logits = torch.matmul(center_embeds, self.outside_embeddings.weight.T)
        probs = torch.softmax(logits, dim=1)
        return probs


# Step 3: Softmax Loss Function
class SoftmaxLoss(nn.Module):
    def __init__(self):
        super(SoftmaxLoss, self).__init__()

    def forward(self, center_embeds, target_indices, model):
        logits = torch.matmul(center_embeds, model.outside_embeddings.weight.T)
        log_probs = torch.log_softmax(logits, dim=1)
        loss = -torch.sum(log_probs[range(log_probs.size(0)), target_indices])
        return loss


# Step 4: Training Loop for Softmax
def train_word2vec_softmax(dataset, embedding_dim=10, epochs=1000, learning_rate=0.01):
    vocab_size = dataset.vocab_size
    model = Word2Vec(vocab_size, embedding_dim)
    loss_fn = SoftmaxLoss()
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)

    for epoch in range(epochs):
        total_loss = 0
        for center_idx, outside_idx in dataset.data:
            # Convert to tensors
            center_tensor = torch.tensor([center_idx], dtype=torch.long)
            outside_tensor = torch.tensor([outside_idx], dtype=torch.long)

            # Forward pass
            center_embeds = model(center_tensor)
            loss = loss_fn(center_embeds, outside_tensor, model)

            # Backward pass
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        print(f"Epoch {epoch + 1}, Loss: {total_loss:.4f}")

    return model


# Example Usage for Softmax
corpus = [
    ["I", "like", "learning", "deep", "learning"],
    ["deep", "learning", "is", "fun"],
    ["word2vec", "uses", "word", "embeddings"]
]

dataset = Word2VecDataset(corpus)
trained_model_softmax = train_word2vec_softmax(dataset)
# Out:
# Epoch 1, Loss: 143.7927
# Epoch 2, Loss: 123.9490
# Epoch 3, Loss: 111.7279
# Epoch 4, Loss: 103.4972
# Epoch 5, Loss: 97.2527
# Epoch 6, Loss: 92.2798
# Epoch 7, Loss: 88.2154
# Epoch 8, Loss: 84.8135
# Epoch 9, Loss: 81.9092
# Epoch 10, Loss: 79.3927
# Epoch 11, Loss: 77.1857
# Epoch 12, Loss: 75.2292
# Epoch 13, Loss: 73.4775
# Epoch 14, Loss: 71.8952
# Epoch 15, Loss: 70.4545
# Epoch 16, Loss: 69.1335
# Epoch 17, Loss: 67.9148
# Epoch 18, Loss: 66.7844
# Epoch 19, Loss: 65.7307
# Epoch 20, Loss: 64.7442
# Epoch 21, Loss: 63.8166
# Epoch 22, Loss: 62.9412
# Epoch 23, Loss: 62.1121
# Epoch 24, Loss: 61.3245
# Epoch 25, Loss: 60.5741
# Epoch 26, Loss: 59.8575
# Epoch 27, Loss: 59.1718
# Epoch 28, Loss: 58.5145
# Epoch 29, Loss: 57.8837
# Epoch 30, Loss: 57.2780
# Epoch 31, Loss: 56.6960
# Epoch 32, Loss: 56.1368
# Epoch 33, Loss: 55.5997
# Epoch 34, Loss: 55.0840
# Epoch 35, Loss: 54.5893
# Epoch 36, Loss: 54.1150
# Epoch 37, Loss: 53.6607
# Epoch 38, Loss: 53.2258
# Epoch 39, Loss: 52.8098
# Epoch 40, Loss: 52.4118
# Epoch 41, Loss: 52.0310
# Epoch 42, Loss: 51.6667
# Epoch 43, Loss: 51.3177
# Epoch 44, Loss: 50.9833
# Epoch 45, Loss: 50.6623
# Epoch 46, Loss: 50.3540
# Epoch 47, Loss: 50.0574
# Epoch 48, Loss: 49.7719
# Epoch 49, Loss: 49.4967
# Epoch 50, Loss: 49.2313
# Epoch 51, Loss: 48.9751
# Epoch 52, Loss: 48.7277
# Epoch 53, Loss: 48.4887
# Epoch 54, Loss: 48.2578
# Epoch 55, Loss: 48.0346
# Epoch 56, Loss: 47.8191
# Epoch 57, Loss: 47.6109
# Epoch 58, Loss: 47.4098
# Epoch 59, Loss: 47.2158
# Epoch 60, Loss: 47.0285
# Epoch 61, Loss: 46.8479
# Epoch 62, Loss: 46.6738
# Epoch 63, Loss: 46.5060
# Epoch 64, Loss: 46.3443
# Epoch 65, Loss: 46.1887
# Epoch 66, Loss: 46.0388
# Epoch 67, Loss: 45.8946
# Epoch 68, Loss: 45.7559
# Epoch 69, Loss: 45.6224
# Epoch 70, Loss: 45.4940
# Epoch 71, Loss: 45.3706
# Epoch 72, Loss: 45.2519
# Epoch 73, Loss: 45.1377
# Epoch 74, Loss: 45.0279
# Epoch 75, Loss: 44.9223
# Epoch 76, Loss: 44.8207
# Epoch 77, Loss: 44.7230
# Epoch 78, Loss: 44.6290
# Epoch 79, Loss: 44.5386
# Epoch 80, Loss: 44.4515
# Epoch 81, Loss: 44.3676
# Epoch 82, Loss: 44.2869
# Epoch 83, Loss: 44.2091
# Epoch 84, Loss: 44.1342
# Epoch 85, Loss: 44.0620
# Epoch 86, Loss: 43.9923
# Epoch 87, Loss: 43.9252
# Epoch 88, Loss: 43.8604
# Epoch 89, Loss: 43.7979
# Epoch 90, Loss: 43.7375
# Epoch 91, Loss: 43.6793
# Epoch 92, Loss: 43.6230
# Epoch 93, Loss: 43.5686
# Epoch 94, Loss: 43.5161
# Epoch 95, Loss: 43.4652
# Epoch 96, Loss: 43.4161
# Epoch 97, Loss: 43.3686
# Epoch 98, Loss: 43.3226
# Epoch 99, Loss: 43.2780
# Epoch 100, Loss: 43.2349
# Epoch 101, Loss: 43.1931
# Epoch 102, Loss: 43.1526
# Epoch 103, Loss: 43.1134
# Epoch 104, Loss: 43.0754
# Epoch 105, Loss: 43.0385
# Epoch 106, Loss: 43.0027
# Epoch 107, Loss: 42.9680
# Epoch 108, Loss: 42.9342
# Epoch 109, Loss: 42.9015
# Epoch 110, Loss: 42.8697
# Epoch 111, Loss: 42.8388
# Epoch 112, Loss: 42.8088
# Epoch 113, Loss: 42.7796
# Epoch 114, Loss: 42.7513
# Epoch 115, Loss: 42.7237
# Epoch 116, Loss: 42.6968
# Epoch 117, Loss: 42.6707
# Epoch 118, Loss: 42.6453
# Epoch 119, Loss: 42.6205
# Epoch 120, Loss: 42.5964
# Epoch 121, Loss: 42.5729
# Epoch 122, Loss: 42.5500
# Epoch 123, Loss: 42.5277
# Epoch 124, Loss: 42.5060
# Epoch 125, Loss: 42.4848
# Epoch 126, Loss: 42.4641
# Epoch 127, Loss: 42.4440
# Epoch 128, Loss: 42.4243
# Epoch 129, Loss: 42.4051
# Epoch 130, Loss: 42.3863
# Epoch 131, Loss: 42.3680
# Epoch 132, Loss: 42.3501
# Epoch 133, Loss: 42.3326
# Epoch 134, Loss: 42.3156
# Epoch 135, Loss: 42.2989
# Epoch 136, Loss: 42.2826
# Epoch 137, Loss: 42.2666
# Epoch 138, Loss: 42.2510
# Epoch 139, Loss: 42.2358
# Epoch 140, Loss: 42.2209
# Epoch 141, Loss: 42.2063
# Epoch 142, Loss: 42.1920
# Epoch 143, Loss: 42.1780
# Epoch 144, Loss: 42.1643
# Epoch 145, Loss: 42.1509
# Epoch 146, Loss: 42.1378
# Epoch 147, Loss: 42.1249
# Epoch 148, Loss: 42.1123
# Epoch 149, Loss: 42.1000
# Epoch 150, Loss: 42.0879
# Epoch 151, Loss: 42.0760
# Epoch 152, Loss: 42.0644
# Epoch 153, Loss: 42.0530
# Epoch 154, Loss: 42.0418
# Epoch 155, Loss: 42.0308
# Epoch 156, Loss: 42.0200
# Epoch 157, Loss: 42.0095
# Epoch 158, Loss: 41.9991
# Epoch 159, Loss: 41.9889
# Epoch 160, Loss: 41.9789
# Epoch 161, Loss: 41.9691
# Epoch 162, Loss: 41.9595
# Epoch 163, Loss: 41.9500
# Epoch 164, Loss: 41.9407
# Epoch 165, Loss: 41.9316
# Epoch 166, Loss: 41.9226
# Epoch 167, Loss: 41.9138
# Epoch 168, Loss: 41.9052
# Epoch 169, Loss: 41.8966
# Epoch 170, Loss: 41.8883
# Epoch 171, Loss: 41.8800
# Epoch 172, Loss: 41.8719
# Epoch 173, Loss: 41.8640
# Epoch 174, Loss: 41.8561
# Epoch 175, Loss: 41.8484
# Epoch 176, Loss: 41.8408
# Epoch 177, Loss: 41.8334
# Epoch 178, Loss: 41.8260
# Epoch 179, Loss: 41.8188
# Epoch 180, Loss: 41.8117
# Epoch 181, Loss: 41.8047
# Epoch 182, Loss: 41.7978
# Epoch 183, Loss: 41.7910
# Epoch 184, Loss: 41.7843
# Epoch 185, Loss: 41.7777
# Epoch 186, Loss: 41.7712
# Epoch 187, Loss: 41.7648
# Epoch 188, Loss: 41.7585
# Epoch 189, Loss: 41.7523
# Epoch 190, Loss: 41.7462
# Epoch 191, Loss: 41.7401
# Epoch 192, Loss: 41.7342
# Epoch 193, Loss: 41.7283
# Epoch 194, Loss: 41.7226
# Epoch 195, Loss: 41.7169
# Epoch 196, Loss: 41.7112
# Epoch 197, Loss: 41.7057
# Epoch 198, Loss: 41.7002
# Epoch 199, Loss: 41.6948
# Epoch 200, Loss: 41.6895
# Epoch 201, Loss: 41.6842
# Epoch 202, Loss: 41.6791
# Epoch 203, Loss: 41.6739
# Epoch 204, Loss: 41.6689
# Epoch 205, Loss: 41.6639
# Epoch 206, Loss: 41.6590
# Epoch 207, Loss: 41.6541
# Epoch 208, Loss: 41.6493
# Epoch 209, Loss: 41.6446
# Epoch 210, Loss: 41.6399
# Epoch 211, Loss: 41.6353
# Epoch 212, Loss: 41.6307
# Epoch 213, Loss: 41.6262
# Epoch 214, Loss: 41.6218
# Epoch 215, Loss: 41.6174
# Epoch 216, Loss: 41.6130
# Epoch 217, Loss: 41.6087
# Epoch 218, Loss: 41.6045
# Epoch 219, Loss: 41.6003
# Epoch 220, Loss: 41.5961
# Epoch 221, Loss: 41.5920
# Epoch 222, Loss: 41.5880
# Epoch 223, Loss: 41.5840
# Epoch 224, Loss: 41.5800
# Epoch 225, Loss: 41.5761
# Epoch 226, Loss: 41.5722
# Epoch 227, Loss: 41.5684
# Epoch 228, Loss: 41.5646
# Epoch 229, Loss: 41.5609
# Epoch 230, Loss: 41.5572
# Epoch 231, Loss: 41.5535
# Epoch 232, Loss: 41.5499
# Epoch 233, Loss: 41.5463
# Epoch 234, Loss: 41.5427
# Epoch 235, Loss: 41.5392
# Epoch 236, Loss: 41.5357
# Epoch 237, Loss: 41.5323
# Epoch 238, Loss: 41.5289
# Epoch 239, Loss: 41.5255
# Epoch 240, Loss: 41.5222
# Epoch 241, Loss: 41.5189
# Epoch 242, Loss: 41.5156
# Epoch 243, Loss: 41.5124
# Epoch 244, Loss: 41.5092
# Epoch 245, Loss: 41.5060
# Epoch 246, Loss: 41.5028
# Epoch 247, Loss: 41.4997
# Epoch 248, Loss: 41.4966
# Epoch 249, Loss: 41.4936
# Epoch 250, Loss: 41.4905
# Epoch 251, Loss: 41.4876
# Epoch 252, Loss: 41.4846
# Epoch 253, Loss: 41.4816
# Epoch 254, Loss: 41.4787
# Epoch 255, Loss: 41.4758
# Epoch 256, Loss: 41.4730
# Epoch 257, Loss: 41.4701
# Epoch 258, Loss: 41.4673
# Epoch 259, Loss: 41.4645
# Epoch 260, Loss: 41.4618
# Epoch 261, Loss: 41.4590
# Epoch 262, Loss: 41.4563
# Epoch 263, Loss: 41.4536
# Epoch 264, Loss: 41.4510
# Epoch 265, Loss: 41.4483
# Epoch 266, Loss: 41.4457
# Epoch 267, Loss: 41.4431
# Epoch 268, Loss: 41.4405
# Epoch 269, Loss: 41.4379
# Epoch 270, Loss: 41.4354
# Epoch 271, Loss: 41.4329
# Epoch 272, Loss: 41.4304
# Epoch 273, Loss: 41.4279
# Epoch 274, Loss: 41.4255
# Epoch 275, Loss: 41.4230
# Epoch 276, Loss: 41.4206
# Epoch 277, Loss: 41.4182
# Epoch 278, Loss: 41.4159
# Epoch 279, Loss: 41.4135
# Epoch 280, Loss: 41.4112
# Epoch 281, Loss: 41.4088
# Epoch 282, Loss: 41.4065
# Epoch 283, Loss: 41.4042
# Epoch 284, Loss: 41.4020
# Epoch 285, Loss: 41.3997
# Epoch 286, Loss: 41.3975
# Epoch 287, Loss: 41.3953
# Epoch 288, Loss: 41.3931
# Epoch 289, Loss: 41.3909
# Epoch 290, Loss: 41.3887
# Epoch 291, Loss: 41.3865
# Epoch 292, Loss: 41.3844
# Epoch 293, Loss: 41.3823
# Epoch 294, Loss: 41.3802
# Epoch 295, Loss: 41.3781
# Epoch 296, Loss: 41.3760
# Epoch 297, Loss: 41.3739
# Epoch 298, Loss: 41.3719
# Epoch 299, Loss: 41.3698
# Epoch 300, Loss: 41.3678
# Epoch 301, Loss: 41.3658
# Epoch 302, Loss: 41.3638
# Epoch 303, Loss: 41.3618
# Epoch 304, Loss: 41.3599
# Epoch 305, Loss: 41.3579
# Epoch 306, Loss: 41.3560
# Epoch 307, Loss: 41.3540
# Epoch 308, Loss: 41.3521
# Epoch 309, Loss: 41.3502
# Epoch 310, Loss: 41.3483
# Epoch 311, Loss: 41.3464
# Epoch 312, Loss: 41.3445
# Epoch 313, Loss: 41.3427
# Epoch 314, Loss: 41.3408
# Epoch 315, Loss: 41.3390
# Epoch 316, Loss: 41.3372
# Epoch 317, Loss: 41.3354
# Epoch 318, Loss: 41.3336
# Epoch 319, Loss: 41.3318
# Epoch 320, Loss: 41.3300
# Epoch 321, Loss: 41.3282
# Epoch 322, Loss: 41.3265
# Epoch 323, Loss: 41.3247
# Epoch 324, Loss: 41.3230
# Epoch 325, Loss: 41.3213
# Epoch 326, Loss: 41.3195
# Epoch 327, Loss: 41.3178
# Epoch 328, Loss: 41.3161
# Epoch 329, Loss: 41.3144
# Epoch 330, Loss: 41.3128
# Epoch 331, Loss: 41.3111
# Epoch 332, Loss: 41.3094
# Epoch 333, Loss: 41.3078
# Epoch 334, Loss: 41.3061
# Epoch 335, Loss: 41.3045
# Epoch 336, Loss: 41.3029
# Epoch 337, Loss: 41.3013
# Epoch 338, Loss: 41.2997
# Epoch 339, Loss: 41.2981
# Epoch 340, Loss: 41.2965
# Epoch 341, Loss: 41.2949
# Epoch 342, Loss: 41.2933
# Epoch 343, Loss: 41.2918
# Epoch 344, Loss: 41.2902
# Epoch 345, Loss: 41.2887
# Epoch 346, Loss: 41.2871
# Epoch 347, Loss: 41.2856
# Epoch 348, Loss: 41.2841
# Epoch 349, Loss: 41.2825
# Epoch 350, Loss: 41.2810
# Epoch 351, Loss: 41.2795
# Epoch 352, Loss: 41.2780
# Epoch 353, Loss: 41.2766
# Epoch 354, Loss: 41.2751
# Epoch 355, Loss: 41.2736
# Epoch 356, Loss: 41.2721
# Epoch 357, Loss: 41.2707
# Epoch 358, Loss: 41.2692
# Epoch 359, Loss: 41.2678
# Epoch 360, Loss: 41.2663
# Epoch 361, Loss: 41.2649
# Epoch 362, Loss: 41.2635
# Epoch 363, Loss: 41.2621
# Epoch 364, Loss: 41.2607
# Epoch 365, Loss: 41.2593
# Epoch 366, Loss: 41.2579
# Epoch 367, Loss: 41.2565
# Epoch 368, Loss: 41.2551
# Epoch 369, Loss: 41.2537
# Epoch 370, Loss: 41.2523
# Epoch 371, Loss: 41.2510
# Epoch 372, Loss: 41.2496
# Epoch 373, Loss: 41.2483
# Epoch 374, Loss: 41.2469
# Epoch 375, Loss: 41.2456
# Epoch 376, Loss: 41.2442
# Epoch 377, Loss: 41.2429
# Epoch 378, Loss: 41.2416
# Epoch 379, Loss: 41.2403
# Epoch 380, Loss: 41.2389
# Epoch 381, Loss: 41.2376
# Epoch 382, Loss: 41.2363
# Epoch 383, Loss: 41.2350
# Epoch 384, Loss: 41.2337
# Epoch 385, Loss: 41.2325
# Epoch 386, Loss: 41.2312
# Epoch 387, Loss: 41.2299
# Epoch 388, Loss: 41.2286
# Epoch 389, Loss: 41.2274
# Epoch 390, Loss: 41.2261
# Epoch 391, Loss: 41.2248
# Epoch 392, Loss: 41.2236
# Epoch 393, Loss: 41.2223
# Epoch 394, Loss: 41.2211
# Epoch 395, Loss: 41.2199
# Epoch 396, Loss: 41.2186
# Epoch 397, Loss: 41.2174
# Epoch 398, Loss: 41.2162
# Epoch 399, Loss: 41.2150
# Epoch 400, Loss: 41.2138
# Epoch 401, Loss: 41.2125
# Epoch 402, Loss: 41.2113
# Epoch 403, Loss: 41.2101
# Epoch 404, Loss: 41.2089
# Epoch 405, Loss: 41.2078
# Epoch 406, Loss: 41.2066
# Epoch 407, Loss: 41.2054
# Epoch 408, Loss: 41.2042
# Epoch 409, Loss: 41.2030
# Epoch 410, Loss: 41.2019
# Epoch 411, Loss: 41.2007
# Epoch 412, Loss: 41.1995
# Epoch 413, Loss: 41.1984
# Epoch 414, Loss: 41.1972
# Epoch 415, Loss: 41.1961
# Epoch 416, Loss: 41.1949
# Epoch 417, Loss: 41.1938
# Epoch 418, Loss: 41.1927
# Epoch 419, Loss: 41.1915
# Epoch 420, Loss: 41.1904
# Epoch 421, Loss: 41.1893
# Epoch 422, Loss: 41.1881
# Epoch 423, Loss: 41.1870
# Epoch 424, Loss: 41.1859
# Epoch 425, Loss: 41.1848
# Epoch 426, Loss: 41.1837
# Epoch 427, Loss: 41.1826
# Epoch 428, Loss: 41.1815
# Epoch 429, Loss: 41.1804
# Epoch 430, Loss: 41.1793
# Epoch 431, Loss: 41.1782
# Epoch 432, Loss: 41.1771
# Epoch 433, Loss: 41.1760
# Epoch 434, Loss: 41.1750
# Epoch 435, Loss: 41.1739
# Epoch 436, Loss: 41.1728
# Epoch 437, Loss: 41.1718
# Epoch 438, Loss: 41.1707
# Epoch 439, Loss: 41.1696
# Epoch 440, Loss: 41.1686
# Epoch 441, Loss: 41.1675
# Epoch 442, Loss: 41.1665
# Epoch 443, Loss: 41.1654
# Epoch 444, Loss: 41.1644
# Epoch 445, Loss: 41.1633
# Epoch 446, Loss: 41.1623
# Epoch 447, Loss: 41.1612
# Epoch 448, Loss: 41.1602
# Epoch 449, Loss: 41.1592
# Epoch 450, Loss: 41.1582
# Epoch 451, Loss: 41.1571
# Epoch 452, Loss: 41.1561
# Epoch 453, Loss: 41.1551
# Epoch 454, Loss: 41.1541
# Epoch 455, Loss: 41.1531
# Epoch 456, Loss: 41.1521
# Epoch 457, Loss: 41.1510
# Epoch 458, Loss: 41.1500
# Epoch 459, Loss: 41.1490
# Epoch 460, Loss: 41.1480
# Epoch 461, Loss: 41.1470
# Epoch 462, Loss: 41.1460
# Epoch 463, Loss: 41.1451
# Epoch 464, Loss: 41.1441
# Epoch 465, Loss: 41.1431
# Epoch 466, Loss: 41.1421
# Epoch 467, Loss: 41.1411
# Epoch 468, Loss: 41.1401
# Epoch 469, Loss: 41.1392
# Epoch 470, Loss: 41.1382
# Epoch 471, Loss: 41.1372
# Epoch 472, Loss: 41.1363
# Epoch 473, Loss: 41.1353
# Epoch 474, Loss: 41.1343
# Epoch 475, Loss: 41.1334
# Epoch 476, Loss: 41.1324
# Epoch 477, Loss: 41.1315
# Epoch 478, Loss: 41.1305
# Epoch 479, Loss: 41.1296
# Epoch 480, Loss: 41.1286
# Epoch 481, Loss: 41.1277
# Epoch 482, Loss: 41.1267
# Epoch 483, Loss: 41.1258
# Epoch 484, Loss: 41.1248
# Epoch 485, Loss: 41.1239
# Epoch 486, Loss: 41.1230
# Epoch 487, Loss: 41.1220
# Epoch 488, Loss: 41.1211
# Epoch 489, Loss: 41.1202
# Epoch 490, Loss: 41.1193
# Epoch 491, Loss: 41.1183
# Epoch 492, Loss: 41.1174
# Epoch 493, Loss: 41.1165
# Epoch 494, Loss: 41.1156
# Epoch 495, Loss: 41.1147
# Epoch 496, Loss: 41.1138
# Epoch 497, Loss: 41.1128
# Epoch 498, Loss: 41.1119
# Epoch 499, Loss: 41.1110
# Epoch 500, Loss: 41.1101
# Epoch 501, Loss: 41.1092
# Epoch 502, Loss: 41.1083
# Epoch 503, Loss: 41.1074
# Epoch 504, Loss: 41.1065
# Epoch 505, Loss: 41.1056
# Epoch 506, Loss: 41.1047
# Epoch 507, Loss: 41.1039
# Epoch 508, Loss: 41.1030
# Epoch 509, Loss: 41.1021
# Epoch 510, Loss: 41.1012
# Epoch 511, Loss: 41.1003
# Epoch 512, Loss: 41.0994
# Epoch 513, Loss: 41.0986
# Epoch 514, Loss: 41.0977
# Epoch 515, Loss: 41.0968
# Epoch 516, Loss: 41.0959
# Epoch 517, Loss: 41.0951
# Epoch 518, Loss: 41.0942
# Epoch 519, Loss: 41.0933
# Epoch 520, Loss: 41.0925
# Epoch 521, Loss: 41.0916
# Epoch 522, Loss: 41.0907
# Epoch 523, Loss: 41.0899
# Epoch 524, Loss: 41.0890
# Epoch 525, Loss: 41.0882
# Epoch 526, Loss: 41.0873
# Epoch 527, Loss: 41.0865
# Epoch 528, Loss: 41.0856
# Epoch 529, Loss: 41.0848
# Epoch 530, Loss: 41.0839
# Epoch 531, Loss: 41.0831
# Epoch 532, Loss: 41.0822
# Epoch 533, Loss: 41.0814
# Epoch 534, Loss: 41.0805
# Epoch 535, Loss: 41.0797
# Epoch 536, Loss: 41.0789
# Epoch 537, Loss: 41.0780
# Epoch 538, Loss: 41.0772
# Epoch 539, Loss: 41.0764
# Epoch 540, Loss: 41.0755
# Epoch 541, Loss: 41.0747
# Epoch 542, Loss: 41.0739
# Epoch 543, Loss: 41.0731
# Epoch 544, Loss: 41.0722
# Epoch 545, Loss: 41.0714
# Epoch 546, Loss: 41.0706
# Epoch 547, Loss: 41.0698
# Epoch 548, Loss: 41.0689
# Epoch 549, Loss: 41.0681
# Epoch 550, Loss: 41.0673
# Epoch 551, Loss: 41.0665
# Epoch 552, Loss: 41.0657
# Epoch 553, Loss: 41.0649
# Epoch 554, Loss: 41.0641
# Epoch 555, Loss: 41.0633
# Epoch 556, Loss: 41.0625
# Epoch 557, Loss: 41.0617
# Epoch 558, Loss: 41.0609
# Epoch 559, Loss: 41.0600
# Epoch 560, Loss: 41.0592
# Epoch 561, Loss: 41.0584
# Epoch 562, Loss: 41.0577
# Epoch 563, Loss: 41.0569
# Epoch 564, Loss: 41.0561
# Epoch 565, Loss: 41.0553
# Epoch 566, Loss: 41.0545
# Epoch 567, Loss: 41.0537
# Epoch 568, Loss: 41.0529
# Epoch 569, Loss: 41.0521
# Epoch 570, Loss: 41.0513
# Epoch 571, Loss: 41.0505
# Epoch 572, Loss: 41.0497
# Epoch 573, Loss: 41.0490
# Epoch 574, Loss: 41.0482
# Epoch 575, Loss: 41.0474
# Epoch 576, Loss: 41.0466
# Epoch 577, Loss: 41.0459
# Epoch 578, Loss: 41.0451
# Epoch 579, Loss: 41.0443
# Epoch 580, Loss: 41.0435
# Epoch 581, Loss: 41.0428
# Epoch 582, Loss: 41.0420
# Epoch 583, Loss: 41.0412
# Epoch 584, Loss: 41.0404
# Epoch 585, Loss: 41.0397
# Epoch 586, Loss: 41.0389
# Epoch 587, Loss: 41.0381
# Epoch 588, Loss: 41.0374
# Epoch 589, Loss: 41.0366
# Epoch 590, Loss: 41.0359
# Epoch 591, Loss: 41.0351
# Epoch 592, Loss: 41.0343
# Epoch 593, Loss: 41.0336
# Epoch 594, Loss: 41.0328
# Epoch 595, Loss: 41.0321
# Epoch 596, Loss: 41.0313
# Epoch 597, Loss: 41.0306
# Epoch 598, Loss: 41.0298
# Epoch 599, Loss: 41.0291
# Epoch 600, Loss: 41.0283
# Epoch 601, Loss: 41.0276
# Epoch 602, Loss: 41.0268
# Epoch 603, Loss: 41.0261
# Epoch 604, Loss: 41.0253
# Epoch 605, Loss: 41.0246
# Epoch 606, Loss: 41.0238
# Epoch 607, Loss: 41.0231
# Epoch 608, Loss: 41.0224
# Epoch 609, Loss: 41.0216
# Epoch 610, Loss: 41.0209
# Epoch 611, Loss: 41.0201
# Epoch 612, Loss: 41.0194
# Epoch 613, Loss: 41.0187
# Epoch 614, Loss: 41.0179
# Epoch 615, Loss: 41.0172
# Epoch 616, Loss: 41.0165
# Epoch 617, Loss: 41.0157
# Epoch 618, Loss: 41.0150
# Epoch 619, Loss: 41.0143
# Epoch 620, Loss: 41.0136
# Epoch 621, Loss: 41.0128
# Epoch 622, Loss: 41.0121
# Epoch 623, Loss: 41.0114
# Epoch 624, Loss: 41.0107
# Epoch 625, Loss: 41.0099
# Epoch 626, Loss: 41.0092
# Epoch 627, Loss: 41.0085
# Epoch 628, Loss: 41.0078
# Epoch 629, Loss: 41.0071
# Epoch 630, Loss: 41.0063
# Epoch 631, Loss: 41.0056
# Epoch 632, Loss: 41.0049
# Epoch 633, Loss: 41.0042
# Epoch 634, Loss: 41.0035
# Epoch 635, Loss: 41.0028
# Epoch 636, Loss: 41.0021
# Epoch 637, Loss: 41.0014
# Epoch 638, Loss: 41.0006
# Epoch 639, Loss: 40.9999
# Epoch 640, Loss: 40.9992
# Epoch 641, Loss: 40.9985
# Epoch 642, Loss: 40.9978
# Epoch 643, Loss: 40.9971
# Epoch 644, Loss: 40.9964
# Epoch 645, Loss: 40.9957
# Epoch 646, Loss: 40.9950
# Epoch 647, Loss: 40.9943
# Epoch 648, Loss: 40.9936
# Epoch 649, Loss: 40.9929
# Epoch 650, Loss: 40.9922
# Epoch 651, Loss: 40.9915
# Epoch 652, Loss: 40.9908
# Epoch 653, Loss: 40.9901
# Epoch 654, Loss: 40.9894
# Epoch 655, Loss: 40.9887
# Epoch 656, Loss: 40.9880
# Epoch 657, Loss: 40.9873
# Epoch 658, Loss: 40.9867
# Epoch 659, Loss: 40.9860
# Epoch 660, Loss: 40.9853
# Epoch 661, Loss: 40.9846
# Epoch 662, Loss: 40.9839
# Epoch 663, Loss: 40.9832
# Epoch 664, Loss: 40.9825
# Epoch 665, Loss: 40.9818
# Epoch 666, Loss: 40.9812
# Epoch 667, Loss: 40.9805
# Epoch 668, Loss: 40.9798
# Epoch 669, Loss: 40.9791
# Epoch 670, Loss: 40.9784
# Epoch 671, Loss: 40.9778
# Epoch 672, Loss: 40.9771
# Epoch 673, Loss: 40.9764
# Epoch 674, Loss: 40.9757
# Epoch 675, Loss: 40.9750
# Epoch 676, Loss: 40.9744
# Epoch 677, Loss: 40.9737
# Epoch 678, Loss: 40.9730
# Epoch 679, Loss: 40.9723
# Epoch 680, Loss: 40.9717
# Epoch 681, Loss: 40.9710
# Epoch 682, Loss: 40.9703
# Epoch 683, Loss: 40.9697
# Epoch 684, Loss: 40.9690
# Epoch 685, Loss: 40.9683
# Epoch 686, Loss: 40.9677
# Epoch 687, Loss: 40.9670
# Epoch 688, Loss: 40.9663
# Epoch 689, Loss: 40.9657
# Epoch 690, Loss: 40.9650
# Epoch 691, Loss: 40.9643
# Epoch 692, Loss: 40.9637
# Epoch 693, Loss: 40.9630
# Epoch 694, Loss: 40.9623
# Epoch 695, Loss: 40.9617
# Epoch 696, Loss: 40.9610
# Epoch 697, Loss: 40.9604
# Epoch 698, Loss: 40.9597
# Epoch 699, Loss: 40.9591
# Epoch 700, Loss: 40.9584
# Epoch 701, Loss: 40.9577
# Epoch 702, Loss: 40.9571
# Epoch 703, Loss: 40.9564
# Epoch 704, Loss: 40.9558
# Epoch 705, Loss: 40.9551
# Epoch 706, Loss: 40.9545
# Epoch 707, Loss: 40.9538
# Epoch 708, Loss: 40.9532
# Epoch 709, Loss: 40.9525
# Epoch 710, Loss: 40.9519
# Epoch 711, Loss: 40.9512
# Epoch 712, Loss: 40.9506
# Epoch 713, Loss: 40.9499
# Epoch 714, Loss: 40.9493
# Epoch 715, Loss: 40.9486
# Epoch 716, Loss: 40.9480
# Epoch 717, Loss: 40.9473
# Epoch 718, Loss: 40.9467
# Epoch 719, Loss: 40.9461
# Epoch 720, Loss: 40.9454
# Epoch 721, Loss: 40.9448
# Epoch 722, Loss: 40.9441
# Epoch 723, Loss: 40.9435
# Epoch 724, Loss: 40.9429
# Epoch 725, Loss: 40.9422
# Epoch 726, Loss: 40.9416
# Epoch 727, Loss: 40.9409
# Epoch 728, Loss: 40.9403
# Epoch 729, Loss: 40.9397
# Epoch 730, Loss: 40.9390
# Epoch 731, Loss: 40.9384
# Epoch 732, Loss: 40.9378
# Epoch 733, Loss: 40.9371
# Epoch 734, Loss: 40.9365
# Epoch 735, Loss: 40.9359
# Epoch 736, Loss: 40.9352
# Epoch 737, Loss: 40.9346
# Epoch 738, Loss: 40.9340
# Epoch 739, Loss: 40.9333
# Epoch 740, Loss: 40.9327
# Epoch 741, Loss: 40.9321
# Epoch 742, Loss: 40.9315
# Epoch 743, Loss: 40.9308
# Epoch 744, Loss: 40.9302
# Epoch 745, Loss: 40.9296
# Epoch 746, Loss: 40.9290
# Epoch 747, Loss: 40.9283
# Epoch 748, Loss: 40.9277
# Epoch 749, Loss: 40.9271
# Epoch 750, Loss: 40.9265
# Epoch 751, Loss: 40.9258
# Epoch 752, Loss: 40.9252
# Epoch 753, Loss: 40.9246
# Epoch 754, Loss: 40.9240
# Epoch 755, Loss: 40.9234
# Epoch 756, Loss: 40.9227
# Epoch 757, Loss: 40.9221
# Epoch 758, Loss: 40.9215
# Epoch 759, Loss: 40.9209
# Epoch 760, Loss: 40.9203
# Epoch 761, Loss: 40.9197
# Epoch 762, Loss: 40.9191
# Epoch 763, Loss: 40.9184
# Epoch 764, Loss: 40.9178
# Epoch 765, Loss: 40.9172
# Epoch 766, Loss: 40.9166
# Epoch 767, Loss: 40.9160
# Epoch 768, Loss: 40.9154
# Epoch 769, Loss: 40.9148
# Epoch 770, Loss: 40.9142
# Epoch 771, Loss: 40.9135
# Epoch 772, Loss: 40.9129
# Epoch 773, Loss: 40.9123
# Epoch 774, Loss: 40.9117
# Epoch 775, Loss: 40.9111
# Epoch 776, Loss: 40.9105
# Epoch 777, Loss: 40.9099
# Epoch 778, Loss: 40.9093
# Epoch 779, Loss: 40.9087
# Epoch 780, Loss: 40.9081
# Epoch 781, Loss: 40.9075
# Epoch 782, Loss: 40.9069
# Epoch 783, Loss: 40.9063
# Epoch 784, Loss: 40.9057
# Epoch 785, Loss: 40.9051
# Epoch 786, Loss: 40.9045
# Epoch 787, Loss: 40.9039
# Epoch 788, Loss: 40.9033
# Epoch 789, Loss: 40.9027
# Epoch 790, Loss: 40.9021
# Epoch 791, Loss: 40.9015
# Epoch 792, Loss: 40.9009
# Epoch 793, Loss: 40.9003
# Epoch 794, Loss: 40.8997
# Epoch 795, Loss: 40.8991
# Epoch 796, Loss: 40.8985
# Epoch 797, Loss: 40.8979
# Epoch 798, Loss: 40.8973
# Epoch 799, Loss: 40.8967
# Epoch 800, Loss: 40.8961
# Epoch 801, Loss: 40.8955
# Epoch 802, Loss: 40.8949
# Epoch 803, Loss: 40.8944
# Epoch 804, Loss: 40.8938
# Epoch 805, Loss: 40.8932
# Epoch 806, Loss: 40.8926
# Epoch 807, Loss: 40.8920
# Epoch 808, Loss: 40.8914
# Epoch 809, Loss: 40.8908
# Epoch 810, Loss: 40.8902
# Epoch 811, Loss: 40.8896
# Epoch 812, Loss: 40.8891
# Epoch 813, Loss: 40.8885
# Epoch 814, Loss: 40.8879
# Epoch 815, Loss: 40.8873
# Epoch 816, Loss: 40.8867
# Epoch 817, Loss: 40.8861
# Epoch 818, Loss: 40.8856
# Epoch 819, Loss: 40.8850
# Epoch 820, Loss: 40.8844
# Epoch 821, Loss: 40.8838
# Epoch 822, Loss: 40.8832
# Epoch 823, Loss: 40.8826
# Epoch 824, Loss: 40.8821
# Epoch 825, Loss: 40.8815
# Epoch 826, Loss: 40.8809
# Epoch 827, Loss: 40.8803
# Epoch 828, Loss: 40.8798
# Epoch 829, Loss: 40.8792
# Epoch 830, Loss: 40.8786
# Epoch 831, Loss: 40.8780
# Epoch 832, Loss: 40.8774
# Epoch 833, Loss: 40.8769
# Epoch 834, Loss: 40.8763
# Epoch 835, Loss: 40.8757
# Epoch 836, Loss: 40.8752
# Epoch 837, Loss: 40.8746
# Epoch 838, Loss: 40.8740
# Epoch 839, Loss: 40.8734
# Epoch 840, Loss: 40.8729
# Epoch 841, Loss: 40.8723
# Epoch 842, Loss: 40.8717
# Epoch 843, Loss: 40.8711
# Epoch 844, Loss: 40.8706
# Epoch 845, Loss: 40.8700
# Epoch 846, Loss: 40.8694
# Epoch 847, Loss: 40.8689
# Epoch 848, Loss: 40.8683
# Epoch 849, Loss: 40.8677
# Epoch 850, Loss: 40.8672
# Epoch 851, Loss: 40.8666
# Epoch 852, Loss: 40.8660
# Epoch 853, Loss: 40.8655
# Epoch 854, Loss: 40.8649
# Epoch 855, Loss: 40.8643
# Epoch 856, Loss: 40.8638
# Epoch 857, Loss: 40.8632
# Epoch 858, Loss: 40.8627
# Epoch 859, Loss: 40.8621
# Epoch 860, Loss: 40.8615
# Epoch 861, Loss: 40.8610
# Epoch 862, Loss: 40.8604
# Epoch 863, Loss: 40.8598
# Epoch 864, Loss: 40.8593
# Epoch 865, Loss: 40.8587
# Epoch 866, Loss: 40.8582
# Epoch 867, Loss: 40.8576
# Epoch 868, Loss: 40.8571
# Epoch 869, Loss: 40.8565
# Epoch 870, Loss: 40.8559
# Epoch 871, Loss: 40.8554
# Epoch 872, Loss: 40.8548
# Epoch 873, Loss: 40.8543
# Epoch 874, Loss: 40.8537
# Epoch 875, Loss: 40.8532
# Epoch 876, Loss: 40.8526
# Epoch 877, Loss: 40.8520
# Epoch 878, Loss: 40.8515
# Epoch 879, Loss: 40.8509
# Epoch 880, Loss: 40.8504
# Epoch 881, Loss: 40.8498
# Epoch 882, Loss: 40.8493
# Epoch 883, Loss: 40.8487
# Epoch 884, Loss: 40.8482
# Epoch 885, Loss: 40.8476
# Epoch 886, Loss: 40.8471
# Epoch 887, Loss: 40.8465
# Epoch 888, Loss: 40.8460
# Epoch 889, Loss: 40.8454
# Epoch 890, Loss: 40.8449
# Epoch 891, Loss: 40.8443
# Epoch 892, Loss: 40.8438
# Epoch 893, Loss: 40.8432
# Epoch 894, Loss: 40.8427
# Epoch 895, Loss: 40.8422
# Epoch 896, Loss: 40.8416
# Epoch 897, Loss: 40.8411
# Epoch 898, Loss: 40.8405
# Epoch 899, Loss: 40.8400
# Epoch 900, Loss: 40.8394
# Epoch 901, Loss: 40.8389
# Epoch 902, Loss: 40.8383
# Epoch 903, Loss: 40.8378
# Epoch 904, Loss: 40.8373
# Epoch 905, Loss: 40.8367
# Epoch 906, Loss: 40.8362
# Epoch 907, Loss: 40.8356
# Epoch 908, Loss: 40.8351
# Epoch 909, Loss: 40.8346
# Epoch 910, Loss: 40.8340
# Epoch 911, Loss: 40.8335
# Epoch 912, Loss: 40.8329
# Epoch 913, Loss: 40.8324
# Epoch 914, Loss: 40.8319
# Epoch 915, Loss: 40.8313
# Epoch 916, Loss: 40.8308
# Epoch 917, Loss: 40.8303
# Epoch 918, Loss: 40.8297
# Epoch 919, Loss: 40.8292
# Epoch 920, Loss: 40.8287
# Epoch 921, Loss: 40.8281
# Epoch 922, Loss: 40.8276
# Epoch 923, Loss: 40.8270
# Epoch 924, Loss: 40.8265
# Epoch 925, Loss: 40.8260
# Epoch 926, Loss: 40.8254
# Epoch 927, Loss: 40.8249
# Epoch 928, Loss: 40.8244
# Epoch 929, Loss: 40.8238
# Epoch 930, Loss: 40.8233
# Epoch 931, Loss: 40.8228
# Epoch 932, Loss: 40.8223
# Epoch 933, Loss: 40.8217
# Epoch 934, Loss: 40.8212
# Epoch 935, Loss: 40.8207
# Epoch 936, Loss: 40.8201
# Epoch 937, Loss: 40.8196
# Epoch 938, Loss: 40.8191
# Epoch 939, Loss: 40.8186
# Epoch 940, Loss: 40.8180
# Epoch 941, Loss: 40.8175
# Epoch 942, Loss: 40.8170
# Epoch 943, Loss: 40.8165
# Epoch 944, Loss: 40.8159
# Epoch 945, Loss: 40.8154
# Epoch 946, Loss: 40.8149
# Epoch 947, Loss: 40.8144
# Epoch 948, Loss: 40.8138
# Epoch 949, Loss: 40.8133
# Epoch 950, Loss: 40.8128
# Epoch 951, Loss: 40.8123
# Epoch 952, Loss: 40.8117
# Epoch 953, Loss: 40.8112
# Epoch 954, Loss: 40.8107
# Epoch 955, Loss: 40.8102
# Epoch 956, Loss: 40.8097
# Epoch 957, Loss: 40.8091
# Epoch 958, Loss: 40.8086
# Epoch 959, Loss: 40.8081
# Epoch 960, Loss: 40.8076
# Epoch 961, Loss: 40.8071
# Epoch 962, Loss: 40.8065
# Epoch 963, Loss: 40.8060
# Epoch 964, Loss: 40.8055
# Epoch 965, Loss: 40.8050
# Epoch 966, Loss: 40.8045
# Epoch 967, Loss: 40.8040
# Epoch 968, Loss: 40.8034
# Epoch 969, Loss: 40.8029
# Epoch 970, Loss: 40.8024
# Epoch 971, Loss: 40.8019
# Epoch 972, Loss: 40.8014
# Epoch 973, Loss: 40.8009
# Epoch 974, Loss: 40.8004
# Epoch 975, Loss: 40.7998
# Epoch 976, Loss: 40.7993
# Epoch 977, Loss: 40.7988
# Epoch 978, Loss: 40.7983
# Epoch 979, Loss: 40.7978
# Epoch 980, Loss: 40.7973
# Epoch 981, Loss: 40.7968
# Epoch 982, Loss: 40.7963
# Epoch 983, Loss: 40.7957
# Epoch 984, Loss: 40.7952
# Epoch 985, Loss: 40.7947
# Epoch 986, Loss: 40.7942
# Epoch 987, Loss: 40.7937
# Epoch 988, Loss: 40.7932
# Epoch 989, Loss: 40.7927
# Epoch 990, Loss: 40.7922
# Epoch 991, Loss: 40.7917
# Epoch 992, Loss: 40.7912
# Epoch 993, Loss: 40.7907
# Epoch 994, Loss: 40.7902
# Epoch 995, Loss: 40.7897
# Epoch 996, Loss: 40.7892
# Epoch 997, Loss: 40.7886
# Epoch 998, Loss: 40.7881
# Epoch 999, Loss: 40.7876
# Epoch 1000, Loss: 40.7871
